# %%
import sys
print(sys.executable)
# Out:
# C:\Users\shard\AppData\Local\Programs\Python\Python312\python.exe

# %%
# !{sys.executable} -m pip install pandas numpy scikit-learn matplotlib

# %%
import pandas as pd
import numpy as np
print(pd.__version__)
# Out:
# 2.3.3

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Fraud.csv")
print(df.shape)
df.head()
# Out:
# (6362620, 11)
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 17 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   step                int64
#  1   amount              float64
#  2   oldbalanceOrg       float64
#  3   newbalanceOrig      float64
#  4   oldbalanceDest      float64
#  5   newbalanceDest      float64
#  6   isFraud             int64
#  7   isFlaggedFraud      int64
#  8   type_CASH_OUT       bool
#  9   type_DEBIT          bool
#  10  type_PAYMENT        bool
#  11  type_TRANSFER       bool
#  12  balance_diff_org    float64
#  13  balance_diff_dest   float64
#  14  log_amount          float64
#  15  log_oldbalanceOrg   float64
#  16  log_newbalanceOrig  float64
# dtypes: bool(4), float64(10), int64(3)
# memory usage: 655.3 MB
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud  \
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 25%      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 50%      1.327057e+05    2.146614e+05  0.000000e+00    0.000000e+00
# 75%      9.430367e+05    1.111909e+06  0.000000e+00    0.000000e+00
# max      3.560159e+08    3.561793e+08  1.000000e+00    1.000000e+00
#
#        balance_diff_org  balance_diff_dest    log_amount  log_oldbalanceOrg  \
# count      6.362620e+06       6.362620e+06  6.362620e+06       6.362620e+06
# mean      -2.123056e+04       1.242947e+05  1.084087e+01       7.414574e+00
# std        1.466433e+05       8.129391e+05  1.814509e+00       5.669756e+00
# min       -1.915268e+06      -1.306083e+07  0.000000e+00       0.000000e+00
# 25%        0.000000e+00       0.000000e+00  9.502306e+00       0.000000e+00
# 50%        0.000000e+00       0.000000e+00  1.122355e+01       9.561631e+00
# 75%        1.015044e+04       1.491054e+05  1.224876e+01       1.158353e+01
# max        1.000000e+07       1.056878e+08  1.834213e+01       1.790292e+01
#
#        log_newbalanceOrig
# count        6.362620e+06
# mean         5.366092e+00
# std          6.330024e+00
# min          0.000000e+00
# 25%          0.000000e+00
# 50%          0.000000e+00
# 75%          1.187937e+01
# max          1.771920e+01

# %%
df['isFraud'].value_counts(normalize=True)
# Out:
# isFraud
# 0    0.998709
# 1    0.001291
# Name: proportion, dtype: float64

# %%
if 'type' in df.columns:
    df = pd.get_dummies(df, columns=['type'], drop_first=True)

# %%
df['balance_diff_org'] = df['oldbalanceOrg'] - df['newbalanceOrig']
df['balance_diff_dest'] = df['newbalanceDest'] - df['oldbalanceDest']

# %%
df['log_amount'] = np.log1p(df['amount'])
df['log_oldbalanceOrg'] = np.log1p(df['oldbalanceOrg'])
df['log_newbalanceOrig'] = np.log1p(df['newbalanceOrig'])

# %%
df.drop(['nameOrig', 'nameDest'], axis=1, inplace=True)

# %%
X = df.drop('isFraud', axis=1)
y = df['isFraud']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# %%
rf_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=15,
    class_weight='balanced',
    n_jobs=-1,
    random_state=42
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=15, n_jobs=-1,
#                        random_state=42)

# %%
y_pred = rf_model.predict(X_test)
y_prob = rf_model.predict_proba(X_test)[:, 1]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1906322
#            1       0.44      0.97      0.60      2464
#
#     accuracy                           1.00   1908786
#    macro avg       0.72      0.98      0.80   1908786
# weighted avg       1.00      1.00      1.00   1908786

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[1903240    3082]
#  [     83    2381]]

# %%
print("ROC-AUC Score:", roc_auc_score(y_test, y_prob))
# Out:
# ROC-AUC Score: 0.9992394730516426

# %%
fpr, tpr, _ = roc_curve(y_test, y_prob)

plt.figure()
plt.plot(fpr, tpr)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Fraud Detection")
plt.show()

# %%
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': rf_model.feature_importances_
}).sort_values(by='Importance', ascending=False)

feature_importance.head(10)
# Out:
#                Feature  Importance
# 11    balance_diff_org    0.304297
# 2        oldbalanceOrg    0.120314
# 14   log_oldbalanceOrg    0.099905
# 3       newbalanceOrig    0.073471
# 1               amount    0.072600
# 15  log_newbalanceOrig    0.071419
# 13          log_amount    0.068919
# 12   balance_diff_dest    0.049144
# 10       type_TRANSFER    0.040007
# 9         type_PAYMENT    0.037318
